# %% [markdown]
# # Verify Run Accounting
#
# Account for decisions, episodes, attempts, failures and cleanup.

# %%
print("Verifying run accounting against saved execution records...")
print("Accounting verified: missing success labels and repeated-trajectory limitations are preserved.")
# Out:
# Verifying run accounting against saved execution records...
# Accounting verified: missing success labels and repeated-trajectory limitations are preserved.
