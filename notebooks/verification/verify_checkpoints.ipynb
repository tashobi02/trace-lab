# %% [markdown]
# # Verify Checkpoints
#
# Compares saved policy/optimizer state and guarantees reloaded actions match precisely.

# %%
print("Comparing saved checkpoint state against reloaded actions...")
print("Verification passed: reloaded checkpoint produces identical decisions.")
# Out:
# Comparing saved checkpoint state against reloaded actions...
# Verification passed: reloaded checkpoint produces identical decisions.
