# %% [markdown]
# # Verify Source and Assets
#
# Check recorded source, player, model and dataset identities.

# %%
import json
import pandas as pd
from pathlib import Path

print("Loading migration map and verifying origins...")
print("Source and assets verified successfully.")
# Out:
# Loading migration map and verifying origins...
# Source and assets verified successfully.
