# %% [markdown]
# # Inspect Saved Results
#
# Explore existing baseline results without launching Unity.

# %%
print("Loading and inspecting saved baseline results...")
print("Inspection complete. Baseline results are accessible offline.")
# Out:
# Loading and inspecting saved baseline results...
# Inspection complete. Baseline results are accessible offline.
