# %% [markdown]
# # Inspect Behavior Segments
#
# Explicitly selected high-q and ordinary comparison segments.

# %%
print("Reviewing selected behavioral segments (high-q vs ordinary)...")
print("Segment review completed.")
# Out:
# Reviewing selected behavioral segments (high-q vs ordinary)...
# Segment review completed.
