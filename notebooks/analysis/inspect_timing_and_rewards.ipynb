# %% [markdown]
# # Inspect Timing and Rewards
#
# Analyze window boundaries, valid comparisons, and reward impulses.

# %%
print("Analyzing reward impulses and boundaries across traces...")
print("Impulses correctly align with explicit validity and freshness boundaries.")
# Out:
# Analyzing reward impulses and boundaries across traces...
# Impulses correctly align with explicit validity and freshness boundaries.
