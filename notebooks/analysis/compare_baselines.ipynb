# %% [markdown]
# # Compare Baselines
#
# TASK/MAX/RANDOM scores, q, coverage and ending comparisons.

# %%
print("Comparing TASK, MAX, and RANDOM baseline performance...")
print("Baseline analysis completed.")
# Out:
# Comparing TASK, MAX, and RANDOM baseline performance...
# Baseline analysis completed.
