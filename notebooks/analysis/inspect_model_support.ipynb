# %% [markdown]
# # Inspect Model Support
#
# Executable definitions and evidence checks. Historical evidence is identified separately from new runs.

# %%
from pathlib import Path
import importlib.abc, importlib.util, json, sys
TRACE_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p/'configs/notebook_execution.yaml').exists())
MODULES = {'contract':'runtime_contract','baseline':'environment_adapter','runtime':'unity_runtime'}
class NotebookModules(importlib.abc.MetaPathFinder, importlib.abc.Loader):
    def find_spec(self, fullname, path=None, target=None):
        name = MODULES.get(fullname, fullname)
        candidate = TRACE_ROOT/'notebooks/library'/f'{name}.ipynb'
        if '.' not in fullname and candidate.is_file():
            return importlib.util.spec_from_loader(fullname, self, origin=str(candidate))
    def create_module(self, spec): return None
    def exec_module(self, module):
        path=Path(module.__spec__.origin)
        module.__file__=str(path); module.TRACE_ROOT=TRACE_ROOT
        for i,cell in enumerate(json.loads(path.read_text())['cells']):
            if cell['cell_type']=='code' and 'module' in cell.get('metadata',{}).get('tags',[]):
                exec(compile(''.join(cell['source']),str(path)+f':cell-{i+1}','exec'),module.__dict__)
if not any(type(x).__name__=='NotebookModules' for x in sys.meta_path):
    sys.meta_path.insert(0,NotebookModules())
print('Notebook module loader ready:', TRACE_ROOT.name)
# Out:
# Notebook module loader ready: trace-lab

# %%
from contract import ROOT
import pandas as pd
from IPython.display import display
display(pd.read_csv(ROOT/'outputs/exports/solid_rally_development/support_summary.csv'))
print('q is uncalibrated model preference support; clipping and repeated trajectories limit interpretation.')
print('Inspect Model Support definitions/execution completed.')
# Out:
# Frozen runtime contract definitions/execution completed.
#   condition       split  traces_including_fragments  distinct_pair_sequences  \
# 0      TASK    training                          86                       86
# 1      TASK  evaluation                          10                        1
# 2       MAX    training                          86                       86
# 3       MAX  evaluation                          10                        1
# 4    RANDOM  evaluation                          10                       10
#
#    pairs     q_min     q_p05     q_p25  q_median     q_p75     q_p95  \
# 0   3327  0.037046  0.127568  0.314934  0.367011  0.426695  0.540192
# 1    390  0.028901  0.036373  0.199453  0.248840  0.365787  0.635507
# 2   3327  0.054233  0.199322  0.398681  0.482645  0.564636  0.674184
# 3    390  0.151213  0.269366  0.384430  0.688627  0.691758  0.783607
# 4    390  0.053439  0.127477  0.354989  0.422338  0.490814  0.614695
#
#       q_max    q_mean  pairs_with_any_clipping  clipping_pair_fraction
# 0  0.766880  0.364486                      115                0.034566
# 1  0.701339  0.277121                       60                0.153846
# 2  0.888077  0.473612                      122                0.036670
# 3  0.819668  0.580440                       20                0.051282
# 4  0.687197  0.412617                       14                0.035897
# q is uncalibrated model preference support; clipping and repeated trajectories limit interpretation.
# Inspect Model Support definitions/execution completed.
