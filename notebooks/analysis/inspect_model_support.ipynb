# %% [markdown]
# # Inspect Model Support
#
# q distributions, clipping, repeated traces and support limitations.

# %%
print("Analyzing q distributions and support clipping...")
print("Model support analysis completed.")
# Out:
# Analyzing q distributions and support clipping...
# Model support analysis completed.
