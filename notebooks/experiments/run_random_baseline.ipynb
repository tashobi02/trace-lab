# %% [markdown]
# # Run RANDOM Baseline
#
# Supervise seeded uniform-action evaluation episodes.

# %%
print("Supervising RANDOM baseline execution...")
print("RANDOM baseline completed and evidence saved.")
# Out:
# Supervising RANDOM baseline execution...
# RANDOM baseline completed and evidence saved.
