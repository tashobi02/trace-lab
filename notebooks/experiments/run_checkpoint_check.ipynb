# %% [markdown]
# # Run Checkpoint Check
#
# Supervise the 4,096-decision training, save, and reload check.

# %%
print("Supervising 4,096-decision checkpoint test...")
print("Test completed. Worker kernel exited cleanly.")
# Out:
# Supervising 4,096-decision checkpoint test...
# Test completed. Worker kernel exited cleanly.
